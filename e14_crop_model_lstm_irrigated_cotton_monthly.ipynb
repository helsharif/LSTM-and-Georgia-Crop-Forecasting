# %%
'''
Husayn El Sharif
Irrigation Cotton Yield & Irrigation Demand Prediction (Southern Georgia Region) using Monthly Weather Data
'''
# Out:
# '\nHusayn El Sharif\nIrrigation Cotton Yield & Irrigation Demand Prediction (Southern Georgia Region) using Monthly Weather Data\n'

# %%
# import libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from keras.models import Sequential
from keras.layers import Input, LSTM, Dropout, Dense, Bidirectional

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split

from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import joblib

from sklearn.metrics import mean_squared_error # Import mean_squared_error from sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_error
# Out:
# 2025-01-13 07:51:07.059663: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-13 07:51:07.069483: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736772667.081195   47580 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736772667.084642   47580 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-13 07:51:07.097494: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
crop_name = 'cotton'

# %%
# Import Crop Model Data

crop_model_data_path = '02 Crop Model Results Agg Spreadsheets (Monthly)/{}_irrigated.xlsx'.format(crop_name)

imported_df_dictionary = pd.read_excel(crop_model_data_path, sheet_name = None)
sheet_names = list(imported_df_dictionary.keys()) # create a list of the sheet names

# %%
# Aggregate X (climate) and y data (yield)
# note: skip data from Years 1982 and 1985

X_list = [] # initialize
y_list = [] # initialize

for s in sheet_names:
    current_df = imported_df_dictionary[s]
    current_year = current_df['Year'].iloc[0]
    if current_year != 1982 and current_year != 1985:
        X_excerpt = current_df[['SRAD', 'TMAX', 'TMIN', 'TAVG', 'PRE']]
        y_excerpt = current_df[['YIELD', 'TOTAL_IRR']].iloc[0]
        X_list.append(X_excerpt)
        y_list.append(y_excerpt)

# convert to numpy arrays
X_data = np.array(X_list)
y_data = np.array(y_list)

# %%
# Samples, features, and targets
num_samples = X_data.shape[0]
num_features = X_data.shape[1]
num_targets = y_data.shape[1]

# %%
# Fit scalers
input_scaler = MinMaxScaler() # initialize
input_scaler = input_scaler.fit(pd.concat(X_list, axis=0))

output_scaler =  MinMaxScaler() # initialize
output_scaler = output_scaler.fit(pd.DataFrame(y_list).reset_index(drop=True))

# %%
# scale data
X_data_scaled_df = pd.DataFrame(input_scaler.transform(pd.concat(X_list, axis=0)), columns=['SRAD', 'TMAX', 'TMIN', 'TAVG', 'PRE'] )
y_data_scaled_df = pd.DataFrame(output_scaler.transform(pd.DataFrame(y_list).reset_index(drop=True)), columns=['YIELD', 'TOTAL_IRR'] )

# %%
X_data_scaled_df.head()
# Out:
#        SRAD      TMAX      TMIN      TAVG       PRE
# 0  0.410229  0.096900  0.282791  0.159480  0.403235
# 1  0.582118  0.370055  0.583349  0.484948  0.326243
# 2  0.702232  0.619770  0.780135  0.735939  0.238167
# 3  0.842816  0.761725  0.891374  0.878245  0.199221
# 4  0.663653  0.739278  0.861680  0.848518  0.212702

# %%
y_data_scaled_df.head()
# Out:
#       YIELD  TOTAL_IRR
# 0  0.414742   0.843373
# 1  0.476909   0.831325
# 2  0.317940   0.843373
# 3  0.523979   0.863454
# 4  0.047957   0.755020

# %%
# split scaled data into samples. Every 7 rows is a sample

# %%
X_data_scaled_list = []
y_data_scaled_list = []

rows_per_sample = 7
for r in range(0, len(X_data_scaled_df), rows_per_sample):
    X_excerpt = X_data_scaled_df.iloc[r:r+rows_per_sample].values
    X_data_scaled_list.append(X_excerpt)

for r in range(0, len(y_data_scaled_df)):
    y_excerpt = y_data_scaled_df.iloc[r].values
    y_data_scaled_list.append(y_excerpt)

# %%
# convert to numpy arrays for LSTM
X_data_scaled_array = np.array(X_data_scaled_list)
y_data_scaled_array = np.array(y_data_scaled_list)

# %%
# Split X_data_scaled_array and y_data_scaled_array into Train (80%, 280 samples), Validation (10%, 35 samples), and Test (10%, 35 smaples) data
X_data_scaled_array_shuffled, y_data_scaled_array_shuffled = shuffle(X_data_scaled_array, y_data_scaled_array, random_state=12232)

# %%
# Split into Train, Val, Test
X_train = X_data_scaled_array_shuffled[0:280]
X_val = X_data_scaled_array_shuffled[280:280+35]
X_test = X_data_scaled_array_shuffled[280+35:280+35+35]

y_train = y_data_scaled_array_shuffled[0:280]
y_val = y_data_scaled_array_shuffled[280:280+35]
y_test = y_data_scaled_array_shuffled[280+35:280+35+35]

# %%
# Build Model

LSTM_Model = Sequential() # initialize

# input layer
LSTM_Model.add(
    Input(
        shape=(X_train.shape[1], X_train.shape[2]) # shape = (number of time steps within a sample, number of features)
    ))

# Hidden Layer 1, with dropout regulariation layer, return sequences
LSTM_Model.add( Bidirectional( LSTM(units=80, return_sequences = True) ) )
LSTM_Model.add(Dropout(0.2))

# Hidden Layer 2, with dropout regulariation layer, return sequences
LSTM_Model.add( Bidirectional( LSTM(units=80, return_sequences = True) ) )
LSTM_Model.add(Dropout(0.2))


# Hidden Layer 3, with dropout regulariation layer, do not return sequences
LSTM_Model.add( Bidirectional( LSTM(units=80, return_sequences = False) ) )
LSTM_Model.add(Dropout(0.2))

# Final Layer, Dense/Output Layer, two outputs (two targets)
LSTM_Model.add( Dense(units=num_targets) )

# Compile model
LSTM_Model.compile( optimizer = "adam", loss = "mean_squared_error")
# Out:
# I0000 00:00:1736772669.975764   47580 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5566 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# Train Model

model_location = "models_monthly/"
model_name = "lstm_irrigated_{}_yield_and_irrigation.model.keras".format(crop_name)
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

history = LSTM_Model.fit(
    x = X_train, 
    y = y_train, 
    epochs= 1000, 
    validation_data=(X_val, y_val),
    batch_size = 100, 
    callbacks = [best_model_checkpoint_callback])
# Out:
# Epoch 1/1000
# I0000 00:00:1736772673.884838   47683 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 326ms/step - loss: 0.2513 - val_loss: 0.0507
# Epoch 2/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0564 - val_loss: 0.0755
# Epoch 3/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0718 - val_loss: 0.0418
# Epoch 4/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0468 - val_loss: 0.0562
# Epoch 5/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0558 - val_loss: 0.0466
# Epoch 6/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0437 - val_loss: 0.0373
# Epoch 7/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0416 - val_loss: 0.0389
# Epoch 8/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0442 - val_loss: 0.0392
# Epoch 9/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0416 - val_loss: 0.0365
# Epoch 10/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0354 - val_loss: 0.0347
# Epoch 11/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0378 - val_loss: 0.0342
# Epoch 12/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0357 - val_loss: 0.0318
# Epoch 13/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0345 - val_loss: 0.0306
# Epoch 14/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0305 - val_loss: 0.0296
# Epoch 15/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0310 - val_loss: 0.0279
# Epoch 16/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0291 - val_loss: 0.0279
# Epoch 17/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.
1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0148 - val_loss: 0.0192
# Epoch 517/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0161 - val_loss: 0.0183
# Epoch 518/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0134 - val_loss: 0.0180
# Epoch 519/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0147 - val_loss: 0.0191
# Epoch 520/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0168 - val_loss: 0.0182
# Epoch 521/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0156 - val_loss: 0.0182
# Epoch 522/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0152 - val_loss: 0.0194
# Epoch 523/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0156 - val_loss: 0.0194
# Epoch 524/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0152 - val_loss: 0.0176
# Epoch 525/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0151 - val_loss: 0.0196
# Epoch 526/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0156 - val_loss: 0.0189
# Epoch 527/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0142 - val_loss: 0.0191
# Epoch 528/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0151 - val_loss: 0.0181
# Epoch 529/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0148 - val_loss: 0.0181
# Epoch 530/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0156 - val_loss: 0.0205
# Epoch 531/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0152 - val_loss: 0.0181
# Epoch 532/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0159 - val_loss: 0.0177
# Epoch 533/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0145 - val_loss: 0.0194
# Epoch 534/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0154 - val_loss: 0.0184
# Epoch 535/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0163 - val_loss: 0.0198
# Epoch 536/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0154 - val_loss: 0.0190
# Epoch 537/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0151 - val_loss: 0.0176
# Epoch 538/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0152 - val_loss: 0.0194
# Epoch 539/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0140 - val_loss: 0.0190
# Epoch 540/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0155 - val_loss: 0.0172
# Epoch 541/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0166 - val_loss: 0.0188
# Epoch 542/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0157 - val_loss: 0.0190
# Epoch 543/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0159 - val_loss: 0.0186
# Epoch 544/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0153 - val_loss: 0.0183
# Epoch 545/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0167 - val_loss: 0.0190
# Epoch 546/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0145 - val_loss: 0.0190
# Epoch 547/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0133 - val_loss: 0.0198
# Epoch 548/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0136 - val_loss: 0.0194
# Epoch 549/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0147 - val_loss: 0.0187
# Epoch 550/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0157 - val_loss: 0.0186
# Epoch 551/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0152 - val_loss: 0.0181
# Epoch 552/1000
# ...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0129 - val_loss: 0.0202
# Epoch 818/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0124 - val_loss: 0.0248
# Epoch 819/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0115 - val_loss: 0.0172
# Epoch 820/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0128 - val_loss: 0.0267
# Epoch 821/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0113 - val_loss: 0.0197
# Epoch 822/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0123 - val_loss: 0.0221
# Epoch 823/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0118 - val_loss: 0.0212
# Epoch 824/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0115 - val_loss: 0.0211
# Epoch 825/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0110 - val_loss: 0.0194
# Epoch 826/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0122 - val_loss: 0.0221
# Epoch 827/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0110 - val_loss: 0.0222
# Epoch 828/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0116 - val_loss: 0.0171
# Epoch 829/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0106 - val_loss: 0.0272
# Epoch 830/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0110 - val_loss: 0.0191
# Epoch 831/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0112 - val_loss: 0.0253
# Epoch 832/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0118 - val_loss: 0.0178
# Epoch 833/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0115 - val_loss: 0.0228
# Epoch 834/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0132 - val_loss: 0.0186
# Epoch 835/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0127 - val_loss: 0.0247
# Epoch 836/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0122 - val_loss: 0.0164
# Epoch 837/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0130 - val_loss: 0.0169
# Epoch 838/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0120 - val_loss: 0.0228
# Epoch 839/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0114 - val_loss: 0.0197
# Epoch 840/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0123 - val_loss: 0.0210
# Epoch 841/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0124 - val_loss: 0.0194
# Epoch 842/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.
predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# reverse scaling
y_train_inv = output_scaler.inverse_transform(y_train)
y_val_inv = output_scaler.inverse_transform(y_val)
y_test_inv = output_scaler.inverse_transform(y_test)

y_train_predict_inv = output_scaler.inverse_transform(y_train_predict)
y_val_predict_inv = output_scaler.inverse_transform(y_val_predict)
y_test_predict_inv = output_scaler.inverse_transform(y_test_predict)

# %%
# plot results as scatter
fig = plt.figure(figsize=(12,6))

plt.subplot(1,2,1) # crop yield

# train (blue)
plt.scatter(x=y_train_inv[:,0], y=y_train_predict_inv[:,0], c='blue')
# val (green)
plt.scatter(x=y_val_inv[:,0], y=y_val_predict_inv[:,0], c='green')
# test (red)
plt.scatter(x=y_test_inv[:,0], y=y_test_predict_inv[:,0], c='red')
plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target')
plt.ylabel('Prediction (kg/ha)')
plt.title('Irrigated Crop Yield')

plt.subplot(1,2,2) # irrigation Demand
# train (blue)
plt.scatter(x=y_train_inv[:,1], y=y_train_predict_inv[:,1], c='blue')
# val (green)
plt.scatter(x=y_val_inv[:,1], y=y_val_predict_inv[:,1], c='green')
# test (red)
plt.scatter(x=y_test_inv[:,1], y=y_test_predict_inv[:,1], c='red')
plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target (mm)')
plt.ylabel('Prediction (mm)')
plt.title('Irrigation Demand')
# Out:
# Text(0.5, 1.0, 'Irrigation Demand')

# %%
# Training Scatter Plot

# plot results as scatter
fig = plt.figure(figsize=(12,6))

plt.subplot(1,2,1) # crop yield

# train (blue)
plt.scatter(x=y_train_inv[:,0], y=y_train_predict_inv[:,0], c='blue')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target')
plt.ylabel('Prediction (kg/ha)')
plt.title('Irrigated Crop Yield')

plt.subplot(1,2,2) # irrigation Demand
# train (blue)
plt.scatter(x=y_train_inv[:,1], y=y_train_predict_inv[:,1], c='blue')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target (mm)')
plt.ylabel('Prediction (mm)')
plt.title('Irrigation Demand')
# Out:
# Text(0.5, 1.0, 'Irrigation Demand')

# %%
# Validation Scatter Plot
# plot results as scatter
fig = plt.figure(figsize=(12,6))

plt.subplot(1,2,1) # crop yield


# val (green)
plt.scatter(x=y_val_inv[:,0], y=y_val_predict_inv[:,0], c='green')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target')
plt.ylabel('Prediction (kg/ha)')
plt.title('Irrigated Crop Yield')

plt.subplot(1,2,2) # irrigation Demand

# val (green)
plt.scatter(x=y_val_inv[:,1], y=y_val_predict_inv[:,1], c='green')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target (mm)')
plt.ylabel('Prediction (mm)')
plt.title('Irrigation Demand')
# Out:
# Text(0.5, 1.0, 'Irrigation Demand')

# %%
# Testing Scatter Plot

# plot results as scatter
fig = plt.figure(figsize=(12,6))

plt.subplot(1,2,1) # crop yield


# test (red)
plt.scatter(x=y_test_inv[:,0], y=y_test_predict_inv[:,0], c='red')
plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target')
plt.ylabel('Prediction (kg/ha)')
plt.title('Irrigated Crop Yield')

plt.subplot(1,2,2) # irrigation Demand

# test (red)
plt.scatter(x=y_test_inv[:,1], y=y_test_predict_inv[:,1], c='red')
plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target (mm)')
plt.ylabel('Prediction (mm)')
plt.title('Irrigation Demand')
# Out:
# Text(0.5, 1.0, 'Irrigation Demand')

# %%
# Performance Metrics: Train

rmse = root_mean_squared_error(y_train_inv[:,0], y_train_predict_inv[:,0])
r2 = r2_score(y_train_inv[:,0], y_train_predict_inv[:,0])
mae = mean_absolute_error(y_train_inv[:,0], y_train_predict_inv[:,0])

print('RMSE: {:.2f} kg/ha '.format(rmse))
print('MAE: {:.2f} kg/ha'.format(mae))
print('R2: {:.2f}'.format(r2))
print('')

rmse = root_mean_squared_error(y_train_inv[:,1], y_train_predict_inv[:,1])
r2 = r2_score(y_train_inv[:,1], y_train_predict_inv[:,1])
mae = mean_absolute_error(y_train_inv[:,1], y_train_predict_inv[:,1])

print('RMSE: {:.2f} mm '.format(rmse))
print('MAE: {:.2f} mm'.format(mae))
print('R2: {:.2f}'.format(r2))
# Out:
# RMSE: 177.92 kg/ha
# MAE: 132.21 kg/ha
# R2: 0.27
#
# RMSE: 15.05 mm
# MAE: 12.44 mm
# R2: 0.93

# %%
# Performance Metrics: Validation

rmse = root_mean_squared_error(y_val_inv[:,0], y_val_predict_inv[:,0])
r2 = r2_score(y_val_inv[:,0], y_val_predict_inv[:,0])
mae = mean_absolute_error(y_val_inv[:,0], y_val_predict_inv[:,0])

print('RMSE: {:.2f} kg/ha '.format(rmse))
print('MAE: {:.2f} kg/ha'.format(mae))
print('R2: {:.2f}'.format(r2))
print('')

rmse = root_mean_squared_error(y_val_inv[:,1], y_val_predict_inv[:,1])
r2 = r2_score(y_val_inv[:,1], y_val_predict_inv[:,1])
mae = mean_absolute_error(y_val_inv[:,1], y_val_predict_inv[:,1])

print('RMSE: {:.2f} mm '.format(rmse))
print('MAE: {:.2f} mm'.format(mae))
print('R2: {:.2f}'.format(r2))
# Out:
# RMSE: 173.21 kg/ha
# MAE: 134.85 kg/ha
# R2: 0.29
#
# RMSE: 18.48 mm
# MAE: 14.90 mm
# R2: 0.89

# %%
# Performance Metrics: Testing

rmse = root_mean_squared_error(y_test_inv[:,0], y_test_predict_inv[:,0])
r2 = r2_score(y_test_inv[:,0], y_test_predict_inv[:,0])
mae = mean_absolute_error(y_test_inv[:,0], y_test_predict_inv[:,0])

print('RMSE: {:.2f} kg/ha '.format(rmse))
print('MAE: {:.2f} kg/ha'.format(mae))
print('R2: {:.2f}'.format(r2))
print('')

rmse = root_mean_squared_error(y_test_inv[:,1], y_test_predict_inv[:,1])
r2 = r2_score(y_test_inv[:,1], y_test_predict_inv[:,1])
mae = mean_absolute_error(y_test_inv[:,1], y_test_predict_inv[:,1])

print('RMSE: {:.2f} mm '.format(rmse))
print('MAE: {:.2f} mm'.format(mae))
print('R2: {:.2f}'.format(r2))
# Out:
# RMSE: 198.55 kg/ha
# MAE: 157.65 kg/ha
# R2: -0.03
#
# RMSE: 17.50 mm
# MAE: 14.00 mm
# R2: 0.91
