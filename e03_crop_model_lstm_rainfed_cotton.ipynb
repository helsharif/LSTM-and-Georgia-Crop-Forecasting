# %%
'''
Husayn El Sharif
Rainfed Cotton Yield Prediction (Southern Georgia Region) using Bi-Weekly Weather Data
'''
# Out:
# '\nHusayn El Sharif\nRainfed Cotton Yield Prediction (Southern Georgia Region) using Bi-Weekly Weather Data\n'

# %%
# import libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from keras.models import Sequential
from keras.layers import Input, LSTM, Dropout, Dense, Bidirectional

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split

from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import joblib

from sklearn.metrics import mean_squared_error # Import mean_squared_error from sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_error
# Out:
# 2025-01-14 07:46:01.625706: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-14 07:46:01.639246: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736858761.651957  925413 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736858761.655576  925413 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-14 07:46:01.670600: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
crop_name = 'cotton'

# %%
# Import Crop Model Data

crop_model_data_path = '01 Crop Model Results Agg Spreadsheets/{}_rainfed.xlsx'.format(crop_name)

imported_df_dictionary = pd.read_excel(crop_model_data_path, sheet_name = None)
sheet_names = list(imported_df_dictionary.keys()) # create a list of the sheet names

# %%
# Aggregate X (climate) and y data (yield)
# note: skip data from Years 1982 and 1985

X_list = [] # initialize
y_list = [] # initialize

for s in sheet_names:
    current_df = imported_df_dictionary[s]
    current_year = current_df['Year'].iloc[0]
    if current_year != 1982 and current_year != 1985:
        X_excerpt = current_df[['SRAD', 'TMAX', 'TMIN', 'TAVG', 'PRE']]
        y_excerpt = current_df[['YIELD']].iloc[0]
        X_list.append(X_excerpt)
        y_list.append(y_excerpt)

# convert to numpy arrays
X_data = np.array(X_list)
y_data = np.array(y_list)

# %%
# Samples, features, and targets
num_samples = X_data.shape[0]
num_features = X_data.shape[1]
num_targets = y_data.shape[1]

# %%
# Fit scalers
input_scaler = MinMaxScaler() # initialize
input_scaler = input_scaler.fit(pd.concat(X_list, axis=0))

output_scaler =  MinMaxScaler() # initialize
output_scaler = output_scaler.fit(pd.DataFrame(y_data))

# %%
# scale data
X_data_scaled_df = pd.DataFrame(input_scaler.transform(pd.concat(X_list, axis=0)), columns=['SRAD', 'TMAX', 'TMIN', 'TAVG', 'PRE'] )
y_data_scaled_df = pd.DataFrame(output_scaler.transform(pd.DataFrame(y_data)), columns=['YIELD'] )

# %%
# split scaled data into samples. Every 16 rows is a sample

# %%
X_data_scaled_list = []
y_data_scaled_list = []

rows_per_sample = 16
for r in range(0, len(X_data_scaled_df), rows_per_sample):
    X_excerpt = X_data_scaled_df.iloc[r:r+rows_per_sample].values
    X_data_scaled_list.append(X_excerpt)

for r in range(0, len(y_data_scaled_df)):
    y_excerpt = y_data_scaled_df.iloc[r].values
    y_data_scaled_list.append(y_excerpt)

# %%
# convert to numpy arrays for LSTM
X_data_scaled_array = np.array(X_data_scaled_list)
y_data_scaled_array = np.array(y_data_scaled_list)

# %%
# Split X_data_scaled_array and y_data_scaled_array into Train (80%, 280 samples), Validation (10%, 35 samples), and Test (10%, 35 smaples) data
X_data_scaled_array_shuffled, y_data_scaled_array_shuffled = shuffle(X_data_scaled_array, y_data_scaled_array, random_state=12232)

# %%
# Split into Train, Val, Test
X_train = X_data_scaled_array_shuffled[0:280]
X_val = X_data_scaled_array_shuffled[280:280+35]
X_test = X_data_scaled_array_shuffled[280+35:280+35+35]

y_train = y_data_scaled_array_shuffled[0:280]
y_val = y_data_scaled_array_shuffled[280:280+35]
y_test = y_data_scaled_array_shuffled[280+35:280+35+35]

# %%
X_train.shape
# Out:
# (280, 16, 5)

# %%
# Build Model

LSTM_Model = Sequential() # initialize

# input layer
LSTM_Model.add(
    Input(
        shape=(X_train.shape[1], X_train.shape[2]) # shape = (number of time steps within a sample, number of features)
    ))

# Hidden Layer 1, with dropout regulariation layer, return sequences
LSTM_Model.add( Bidirectional( LSTM(units=100, return_sequences = True) ) )
LSTM_Model.add(Dropout(0.2))

# Hidden Layer 2, with dropout regulariation layer, return sequences
LSTM_Model.add( Bidirectional( LSTM(units=100, return_sequences = True) ) )
LSTM_Model.add(Dropout(0.2))




# Hidden Layer 1, with dropout regulariation layer, return sequences
LSTM_Model.add( Bidirectional( LSTM(units=100, return_sequences = True) ) )
LSTM_Model.add(Dropout(0.2))

# Hidden Layer 2, with dropout regulariation layer, return sequences
LSTM_Model.add( Bidirectional( LSTM(units=100, return_sequences = True) ) )
LSTM_Model.add(Dropout(0.2))

# Hidden Layer 1, with dropout regulariation layer, return sequences
LSTM_Model.add( Bidirectional( LSTM(units=100, return_sequences = True) ) )
LSTM_Model.add(Dropout(0.2))

# Hidden Layer 2, with dropout regulariation layer, return sequences
LSTM_Model.add( Bidirectional( LSTM(units=100, return_sequences = True) ) )
LSTM_Model.add(Dropout(0.2))












# Hidden Layer 3, with dropout regulariation layer, do not return sequences
LSTM_Model.add( Bidirectional( LSTM(units=100, return_sequences = False) ) )
LSTM_Model.add(Dropout(0.2))

# Final Layer, Dense/Output Layer
LSTM_Model.add( Dense(units=1) )

# Compile model
LSTM_Model.compile( optimizer = "adam", loss = "mean_squared_error")
# Out:
# I0000 00:00:1736858764.478408  925413 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 826 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# Train Model

model_location = "models/"
model_name = "lstm_rainfed_{}_yield.model.keras".format(crop_name)
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

history = LSTM_Model.fit(
    x = X_train, 
    y = y_train, 
    epochs= 1000, 
    validation_data=(X_val, y_val),
    batch_size = 100, 
    callbacks = [best_model_checkpoint_callback])
# Out:
# Epoch 1/1000
# I0000 00:00:1736858770.111138  925493 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 625ms/step - loss: 0.2666 - val_loss: 0.0340
# Epoch 2/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0739 - val_loss: 0.0840
# Epoch 3/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0720 - val_loss: 0.0405
# Epoch 4/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - loss: 0.0473 - val_loss: 0.0291
# Epoch 5/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0306 - val_loss: 0.0368
# Epoch 6/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 0.0421 - val_loss: 0.0280
# Epoch 7/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0338 - val_loss: 0.0313
# Epoch 8/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - loss: 0.0325 - val_loss: 0.0277
# Epoch 9/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0335 - val_loss: 0.0288
# Epoch 10/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - loss: 0.0338 - val_loss: 0.0274
# Epoch 11/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0337 - val_loss: 0.0288
# Epoch 12/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step - loss: 0.0338 - val_loss: 0.0270
# Epoch 13/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0332 - val_loss: 0.0273
# Epoch 14/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0320 - val_loss: 0.0273
# Epoch 15/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0319 - val_loss: 0.0262
# Epoch 16/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 0.0315 - val_loss: 0.0257
# Epoch 17/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0343 - val_loss: 0.0250
# Epoch 18/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - loss: 0.0300 - val_loss: 0.0242
# Epoch 19/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.0304 - val_loss: 0.0230
# Epoch 20/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 0.0289 - val_loss: 0.0214
# Epoch 21/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0274 - val_loss: 0.0220
# Epoch 22/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.0285 - val_loss: 0.0201
# Epoch 23/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0280 - val_loss: 0.0256
# Epoch 24/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0306 - val_loss: 0.0209
# Epoch 25/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0264 - val_loss: 0.0207
# Epoch 26/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.0288 - val_loss: 0.0192
# Epoch 27/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0228 - val_loss: 0.0195
# Epoch 28/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.0233 - val_loss: 0.0187
# Epoch 29/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0241 - val_loss: 0.0188
# Epoch 30/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.
1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0114 - val_loss: 0.0124
# Epoch 429/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 430/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 431/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 432/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0101 - val_loss: 0.0115
# Epoch 433/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0102 - val_loss: 0.0116
# Epoch 434/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0097 - val_loss: 0.0113
# Epoch 435/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0106 - val_loss: 0.0125
# Epoch 436/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0096 - val_loss: 0.0124
# Epoch 437/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0089 - val_loss: 0.0130
# Epoch 438/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0104 - val_loss: 0.0122
# Epoch 439/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0102 - val_loss: 0.0120
# Epoch 440/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0093 - val_loss: 0.0127
# Epoch 441/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0108 - val_loss: 0.0122
# Epoch 442/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0092 - val_loss: 0.0114
# Epoch 443/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0102 - val_loss: 0.0123
# Epoch 444/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0101 - val_loss: 0.0119
# Epoch 445/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0084 - val_loss: 0.0109
# Epoch 446/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0101 - val_loss: 0.0112
# Epoch 447/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0093 - val_loss: 0.0145
# Epoch 448/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0100 - val_loss: 0.0133
# Epoch 449/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 450/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0100 - val_loss: 0.0108
# Epoch 451/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0091 - val_loss: 0.0137
# Epoch 452/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0091 - val_loss: 0.0141
# Epoch 453/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0093 - val_loss: 0.0109
# Epoch 454/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 455/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0099 - val_loss: 0.0110
# Epoch 456/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0099 - val_loss: 0.0132
# Epoch 457/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0083 - val_loss: 0.0124
# Epoch 458/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0099 - val_loss: 0.0114
# Epoch 459/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0096 - val_loss: 0.0117
# Epoch 460/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0104 - val_loss: 0.0117
# Epoch 461/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0097 - val_loss: 0.0102
# Epoch 462/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0099 - val_loss: 0.0113
# Epoch 463/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0095 - val_loss: 0.0114
# Epoch 464/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0093 - val_loss: 0.0128
# Epoch 465/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0090 - val_loss: 0.0111
# Epoch 466/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 467/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0091 - val_loss: 0.0102
# Epoch 468/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0102 - val_loss: 0.0121
# Epoch 469/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 470/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0103 - val_loss: 0.0100
# Epoch 471/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0094 - val_loss: 0.0149
# Epoch 472/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0098 - val_loss: 0.0113
# Epoch 473/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0112 - val_loss: 0.0128
# Epoch 474/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0103 - val_loss: 0.0129
# Epoch 475/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0095 - val_loss: 0.0156
# Epoch 476/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0101 - val_loss: 0.0104
# Epoch 477/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0094 - val_loss: 0.0104
# Epoch 478/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0087 - val_loss: 0.0109
# Epoch 479/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0096 - val_loss: 0.0141
# Epoch 480/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0108 - val_loss: 0.0097
# Epoch 481/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.0119 - val_loss: 0.0094
# Epoch 482/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0105 - val_loss: 0.0123
# Epoch 483/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0101 - val_loss: 0.0129
# Epoch 484/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0109 - val_loss: 0.0121
# Epoch 485/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0099 - val_loss: 0.0111
# Epoch 486/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0098 - val_loss: 0.0128
# Epoch 487/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0089 - val_loss: 0.0122
# Epoch 488/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0110 - val_loss: 0.0124
# Epoch 489/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0094 - val_loss: 0.0119
# Epoch 490/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0094 - val_loss: 0.0111
# Epoch 491/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0091 - val_loss: 0.0102
# Epoch 492/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0085 - val_loss: 0.0128
# Epoch 493/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0096 - val_loss: 0.0119
# Epoch 494/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0081 - val_loss: 0.0125
# Epoch 495/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0096 - val_loss: 0.0106
# Epoch 496/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0088 - val_loss: 0.0143
# Epoch 497/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0096 - val_loss: 0.0117
# Epoch 498/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0094 - val_loss: 0.0110
# Epoch 499/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0095 - val_loss: 0.0114
# Epoch 500/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0091 - val_loss: 0.0119
# Epoch 501/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0084 - val_loss: 0.0130
# Epoch 502/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0083 - val_loss: 0.0116
# Epoch 503/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0095 - val_loss: 0.0108
# Epoch 504/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0092 - val_loss: 0.0155
# Epoch 505/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0090 - val_loss: 0.0112
# Epoch 506/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0094 - val_loss: 0.0139
# Epoch 507/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0088 - val_loss: 0.0131
# Epoch 508/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0089 - val_loss: 0.0113
# Epoch 509/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0083 - val_loss: 0.0145
# Epoch 510/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0086 - val_loss: 0.0110
# Epoch 511/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0085 - val_loss: 0.0167
# Epoch 512/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0098 - val_loss: 0.0111
# Epoch 513/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0087 - val_loss: 0.0152
# Epoch 514/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0097 - val_loss: 0.0102
# Epoch 515/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0093 - val_loss: 0.0128
# Epoch 516/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0092 - val_loss: 0.0118
# Epoch 517/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0103 - val_loss: 0.0147
# Epoch 518/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0095 - val_loss: 0.0151
# Epoch 519/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0099 - val_loss: 0.0124
# Epoch 520/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0094 - val_loss: 0.0143
# Epoch 521/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0086 - val_loss: 0.0166
# Epoch 522/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0096 - val_loss: 0.0137
# Epoch 523/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0097 - val_loss: 0.0108
# Epoch 524/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0088 - val_loss: 0.0107
# Epoch 525/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0081 - val_loss: 0.0112
# Epoch 526/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - loss: 0.0126 - val_loss: 0.0087
# Epoch 527/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0126 - val_loss: 0.0113
# Epoch 528/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0093 - val_loss: 0.0145
# Epoch 529/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0115 - val_loss: 0.0153
# Epoch 530/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0105 - val_loss: 0.0133
# Epoch 531/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0097 - val_loss: 0.0140
# Epoch 532/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0093 - val_loss: 0.0133
# Epoch 533/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0087 - val_loss: 0.0152
# Epoch 534/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0087 - val_loss: 0.0118
# Epoch 535/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0087 - val_loss: 0.0128
# Epoch 536/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0079 - val_loss: 0.0132
# Epoch 537/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0080 - val_loss: 0.0140
# Epoch 538/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0084 - val_loss: 0.0101
# Epoch 539/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0094 - val_loss: 0.0140
# Epoch 540/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0086 - val_loss: 0.0158
# Epoch 541/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 542/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0087 - val_loss: 0.0110
# Epoch 543/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0081 - val_loss: 0.0134
# Epoch 544/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0080 - val_loss: 0.0107
# Epoch 545/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0089 - val_loss: 0.0139
# Epoch 546/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0083 - val_loss: 0.0146
# Epoch 547/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0093 - val_loss: 0.0127
# Epoch 548/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0082 - val_loss: 0.0187
# Epoch 549/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0119 - val_loss: 0.0094
# Epoch 550/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0108 - val_loss: 0.0142
# Epoch 551/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0088 - val_loss: 0.0136
# Epoch 552/1000
# ...
# Epoch 818/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0084 - val_loss: 0.0118
# Epoch 819/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0076 - val_loss: 0.0121
# Epoch 820/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0084 - val_loss: 0.0114
# Epoch 821/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0073 - val_loss: 0.0117
# Epoch 822/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0076 - val_loss: 0.0116
# Epoch 823/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0073 - val_loss: 0.0118
# Epoch 824/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0083 - val_loss: 0.0157
# Epoch 825/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0080 - val_loss: 0.0116
# Epoch 826/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0086 - val_loss: 0.0133
# Epoch 827/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0072 - val_loss: 0.0111
# Epoch 828/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0078 - val_loss: 0.0115
# Epoch 829/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0076 - val_loss: 0.0204
# Epoch 830/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0107 - val_loss: 0.0096
# Epoch 831/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0090 - val_loss: 0.0135
# Epoch 832/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0085 - val_loss: 0.0127
# Epoch 833/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0108 - val_loss: 0.0138
# Epoch 834/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0085 - val_loss: 0.0112
# Epoch 835/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0077 - val_loss: 0.0138
# Epoch 836/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0073 - val_loss: 0.0130
# Epoch 837/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0071 - val_loss: 0.0120
# Epoch 838/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0072 - val_loss: 0.0121
# Epoch 839/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0076 - val_loss: 0.0141
# Epoch 840/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0084 - val_loss: 0.0146
# Epoch 841/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0072 - val_loss: 0.0106
# Epoch 842/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0069 - val_loss: 0.0142
# Epoch 843/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0070 - val_loss: 0.0137
# Epoch 844/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0083 - val_loss: 0.0127
# Epoch 845/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0080 - val_loss: 0.0154
# Epoch 846/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0079 - val_loss: 0.0114
# Epoch 847/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0081 - val_loss: 0.0177
# Epoch 848/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0095 - val_loss: 0.0106
# Epoch 849/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0100 - val_loss: 0.0155
# Epoch 850/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0089 - val_loss: 0.0115
# Epoch 851/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0079 - val_loss: 0.0156
# Epoch 852/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0090 - val_loss: 0.0109
# Epoch 853/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0083 - val_loss: 0.0088
# Epoch 854/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0102 - val_loss: 0.0130
# Epoch 855/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0087 - val_loss: 0.0113
# Epoch 856/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0094 - val_loss: 0.0154
# Epoch 857/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0075 - val_loss: 0.0120
# Epoch 858/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0068 - val_loss: 0.0124
# Epoch 859/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0066 - val_loss: 0.0113
# Epoch 860/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0080 - val_loss: 0.0130
# Epoch 861/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0076 - val_loss: 0.0139
# Epoch 862/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0069 - val_loss: 0.0128
# Epoch 863/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0064 - val_loss: 0.0156
# Epoch 864/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0071 - val_loss: 0.0123
# Epoch 865/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0072 - val_loss: 0.0120
# Epoch 866/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0067 - val_loss: 0.0166
# Epoch 867/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0070 - val_loss: 0.0121
# Epoch 868/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0080 - val_loss: 0.0158
# Epoch 869/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0072 - val_loss: 0.0138
# Epoch 870/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0076 - val_loss: 0.0113
# Epoch 871/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0072 - val_loss: 0.0166
# Epoch 872/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0075 - val_loss: 0.0129
# Epoch 873/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0067 - val_loss: 0.0123
# Epoch 874/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0056 - val_loss: 0.0145
# Epoch 875/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0081 - val_loss: 0.0169
# Epoch 876/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0075 - val_loss: 0.0147
# Epoch 877/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0062 - val_loss: 0.0129
# Epoch 878/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0076 - val_loss: 0.0162
# Epoch 879/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0074 - val_loss: 0.0125
# Epoch 880/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0067 - val_loss: 0.0164
# Epoch 881/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0067 - val_loss: 0.0151
# Epoch 882/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0070 - val_loss: 0.0129
# Epoch 883/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0070 - val_loss: 0.0154
# Epoch 884/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0066 - val_loss: 0.0127
# Epoch 885/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0077 - val_loss: 0.0131
# Epoch 886/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0073 - val_loss: 0.0181
# Epoch 887/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0082 - val_loss: 0.0112
# Epoch 888/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0078 - val_loss: 0.0200
# Epoch 889/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0083 - val_loss: 0.0138
# Epoch 890/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0097 - val_loss: 0.0149
# Epoch 891/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0085 - val_loss: 0.0107
# Epoch 892/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0087 - val_loss: 0.0112
# Epoch 893/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0081 - val_loss: 0.0169
# Epoch 894/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0082 - val_loss: 0.0118
# Epoch 895/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0092 - val_loss: 0.0141
# Epoch 896/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0079 - val_loss: 0.0128
# Epoch 897/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0066 - val_loss: 0.0131
# Epoch 898/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0066 - val_loss: 0.0133
# Epoch 899/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0072 - val_loss: 0.0142
# Epoch 900/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0067 - val_loss: 0.0174
# Epoch 901/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0070 - val_loss: 0.0120
# Epoch 902/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0071 - val_loss: 0.0165
# Epoch 903/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0070 - val_loss: 0.0117
# Epoch 904/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0066 - val_loss: 0.0130
# Epoch 905/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0064 - val_loss: 0.0120
# Epoch 906/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0058 - val_loss: 0.0146
# Epoch 907/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0064 - val_loss: 0.0160
# Epoch 908/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0059 - val_loss: 0.0172
# Epoch 909/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0062 - val_loss: 0.0125
# Epoch 910/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.
predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
# reverse scaling
y_train_inv = output_scaler.inverse_transform(y_train)
y_val_inv = output_scaler.inverse_transform(y_val)
y_test_inv = output_scaler.inverse_transform(y_test)

y_train_predict_inv = output_scaler.inverse_transform(y_train_predict)
y_val_predict_inv = output_scaler.inverse_transform(y_val_predict)
y_test_predict_inv = output_scaler.inverse_transform(y_test_predict)

# %%
# plot results as scatter
plt.figure(figsize=(6,6))

# train (blue)
plt.scatter(x=y_train_inv, y=y_train_predict_inv, c='blue')

# val (green)
plt.scatter(x=y_val_inv, y=y_val_predict_inv, c='green')

# test (red)
plt.scatter(x=y_test_inv, y=y_test_predict_inv, c='red')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target (kg/ha)')
plt.ylabel('Prediction (kg/ha)')
plt.title('Crop Yield')
# Out:
# Text(0.5, 1.0, 'Crop Yield')

# %%
# Training Scatter Plot

# plot results as scatter
plt.figure(figsize=(6,6))

# train (blue)
plt.scatter(x=y_train_inv, y=y_train_predict_inv, c='blue')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')

plt.xlabel('Target (kg/ha)')
plt.ylabel('Prediction (kg/ha)')
plt.title('Crop Yield (Training)')
# Out:
# Text(0.5, 1.0, 'Crop Yield (Training)')

# %%
# Validation Scatter Plot
# plot results as scatter
plt.figure(figsize=(6,6))


# val (green)
plt.scatter(x=y_val_inv, y=y_val_predict_inv, c='green')


plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')

plt.xlabel('Target (kg/ha)')
plt.ylabel('Prediction (kg/ha)')
plt.title('Crop Yield (Validation)')
# Out:
# Text(0.5, 1.0, 'Crop Yield (Validation)')

# %%
# Testing Scatter Plot

# plot results as scatter
plt.figure(figsize=(6,6))

# test (red)
plt.scatter(x=y_test_inv, y=y_test_predict_inv, c='red')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')

plt.xlabel('Target (kg/ha)')
plt.ylabel('Prediction (kg/ha)')
plt.title('Crop Yield (Testing)')
# Out:
# Text(0.5, 1.0, 'Crop Yield (Testing)')

# %%
# Performance Metrics: Train

rmse = root_mean_squared_error(y_train_inv, y_train_predict_inv)
r2 = r2_score(y_train_inv, y_train_predict_inv)
mae = mean_absolute_error(y_train_inv, y_train_predict_inv)

print('RMSE: {:.2f} kg/ha '.format(rmse))
print('MAE: {:.2f} kg/ha'.format(mae))
print('R2: {:.2f}'.format(r2))
# Out:
# RMSE: 179.82 kg/ha
# MAE: 139.96 kg/ha
# R2: 0.66

# %%
# Performance Metrics: Validation

rmse = root_mean_squared_error(y_val_inv, y_val_predict_inv)
r2 = r2_score(y_val_inv, y_val_predict_inv)
mae = mean_absolute_error(y_val_inv, y_val_predict_inv)

print('RMSE: {:.2f} kg/ha '.format(rmse))
print('MAE: {:.2f} kg/ha'.format(mae))
print('R2: {:.2f}'.format(r2))
# Out:
# RMSE: 160.73 kg/ha
# MAE: 126.94 kg/ha
# R2: 0.69

# %%
# Performance Metrics: Testing

rmse = root_mean_squared_error(y_test_inv, y_test_predict_inv)
r2 = r2_score(y_test_inv, y_test_predict_inv)
mae = mean_absolute_error(y_test_inv, y_test_predict_inv)

print('RMSE: {:.2f} kg/ha '.format(rmse))
print('MAE: {:.2f} kg/ha'.format(mae))
print('R2: {:.2f}'.format(r2))
# Out:
# RMSE: 149.08 kg/ha
# MAE: 126.68 kg/ha
# R2: 0.73
