# %%
'''
Husayn El Sharif
Irrigation Corn Yield & Irrigation Demand Prediction (Southern Georgia Region) using Bi-Weekly Weather Data
'''
# Out:
# '\nHusayn El Sharif\nIrrigation Corn Yield & Irrigation Demand Prediction (Southern Georgia Region) using Bi-Weekly Weather Data\n'

# %%
# import libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from keras.models import Sequential
from keras.layers import Input, LSTM, Dropout, Dense

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split

from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import joblib

from sklearn.metrics import mean_squared_error # Import mean_squared_error from sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_error
# Out:
# 2025-01-01 19:38:11.345816: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-01 19:38:11.369970: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735778291.386052  115115 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735778291.390809  115115 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-01 19:38:11.417474: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Import Crop Model Data

crop_model_data_path = '01 Crop Model Results Agg Spreadsheets/corn_irrigated.xlsx'

imported_df_dictionary = pd.read_excel(crop_model_data_path, sheet_name = None)
sheet_names = list(imported_df_dictionary.keys()) # create a list of the sheet names

# %%
# Aggregate X (climate) and y data (yield)
# note: skip data from Years 1982 and 1985

X_list = [] # initialize
y_list = [] # initialize

for s in sheet_names:
    current_df = imported_df_dictionary[s]
    current_year = current_df['Year'].iloc[0]
    if current_year != 1982 and current_year != 1985:
        X_excerpt = current_df[['SRAD', 'TMAX', 'TMIN', 'TAVG', 'PRE']]
        y_excerpt = current_df[['YIELD', 'TOTAL_IRR']].iloc[0]
        X_list.append(X_excerpt)
        y_list.append(y_excerpt)

# convert to numpy arrays
X_data = np.array(X_list)
y_data = np.array(y_list)

# %%
# Samples, features, and targets
num_samples = X_data.shape[0]
num_features = X_data.shape[1]
num_targets = y_data.shape[1]

# %%
# Fit scalers
input_scaler = MinMaxScaler() # initialize
input_scaler = input_scaler.fit(pd.concat(X_list, axis=0))

output_scaler =  MinMaxScaler() # initialize
output_scaler = output_scaler.fit(pd.DataFrame(y_list).reset_index(drop=True))

# %%
# scale data
X_data_scaled_df = pd.DataFrame(input_scaler.transform(pd.concat(X_list, axis=0)), columns=['SRAD', 'TMAX', 'TMIN', 'TAVG', 'PRE'] )
y_data_scaled_df = pd.DataFrame(output_scaler.transform(pd.DataFrame(y_list).reset_index(drop=True)), columns=['YIELD', 'TOTAL_IRR'] )

# %%
X_data_scaled_df.head()
# Out:
#        SRAD      TMAX      TMIN      TAVG       PRE
# 0  0.378971  0.310209  0.288897  0.300347  0.302557
# 1  0.619516  0.393652  0.345311  0.375571  0.175426
# 2  0.576399  0.410995  0.434423  0.430528  0.107244
# 3  0.536687  0.578207  0.642831  0.629724  0.279474
# 4  0.954236  0.718586  0.708229  0.741282  0.017756

# %%
y_data_scaled_df.head()
# Out:
#       YIELD  TOTAL_IRR
# 0  0.748893   0.434066
# 1  0.751044   0.442308
# 2  0.756107   0.434066
# 3  0.704341   0.434066
# 4  0.757499   0.373626

# %%
# split scaled data into samples. Every 16 rows is a sample

# %%
X_data_scaled_list = []
y_data_scaled_list = []

rows_per_sample = 16
for r in range(0, len(X_data_scaled_df), rows_per_sample):
    X_excerpt = X_data_scaled_df.iloc[r:r+rows_per_sample].values
    X_data_scaled_list.append(X_excerpt)

for r in range(0, len(y_data_scaled_df)):
    y_excerpt = y_data_scaled_df.iloc[r].values
    y_data_scaled_list.append(y_excerpt)

# %%
# convert to numpy arrays for LSTM
X_data_scaled_array = np.array(X_data_scaled_list)
y_data_scaled_array = np.array(y_data_scaled_list)

# %%
# Split X_data_scaled_array and y_data_scaled_array into Train (80%, 280 samples), Validation (10%, 35 samples), and Test (10%, 35 smaples) data
X_data_scaled_array_shuffled, y_data_scaled_array_shuffled = shuffle(X_data_scaled_array, y_data_scaled_array, random_state=12232)

# %%
# Split into Train, Val, Test
X_train = X_data_scaled_array_shuffled[0:280]
X_val = X_data_scaled_array_shuffled[280:280+35]
X_test = X_data_scaled_array_shuffled[280+35:280+35+35]

y_train = y_data_scaled_array_shuffled[0:280]
y_val = y_data_scaled_array_shuffled[280:280+35]
y_test = y_data_scaled_array_shuffled[280+35:280+35+35]

# %%
# Build Model

LSTM_Model = Sequential() # initialize

# input layer
LSTM_Model.add(
    Input(
        shape=(X_train.shape[1], X_train.shape[2]) # shape = (number of time steps within a sample, number of features)
    ))

# Hidden Layer 1, with dropout regulariation layer, return sequences
LSTM_Model.add( LSTM(units=50, return_sequences = True) )
LSTM_Model.add(Dropout(0.2))

# Hidden Layer 2, with dropout regulariation layer, return sequences
LSTM_Model.add( LSTM(units=50, return_sequences = True) )
LSTM_Model.add(Dropout(0.2))

# Hidden Layer 3, with dropout regulariation layer, do not return sequences
LSTM_Model.add( LSTM(units=50, return_sequences = False) )
LSTM_Model.add(Dropout(0.2))

# Final Layer, Dense/Output Layer, two outputs (two targets)
LSTM_Model.add( Dense(units=num_targets) )

# Compile model
LSTM_Model.compile( optimizer = "adam", loss = "mean_squared_error")
# Out:
# I0000 00:00:1735779022.038447  115115 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5566 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# Train Model

model_location = "models/"
model_name = "lstm_irrigated_corn_yield_and_irrigation.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

history = LSTM_Model.fit(
    x = X_train, 
    y = y_train, 
    epochs=200, 
    validation_data=(X_val, y_val),
    batch_size = 20, 
    callbacks = [best_model_checkpoint_callback])
# Out:
# Epoch 1/200
# I0000 00:00:1735779036.487396  118413 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.1227 - val_loss: 0.0538
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0579 - val_loss: 0.0406
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0467 - val_loss: 0.0438
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0442 - val_loss: 0.0399
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0382 - val_loss: 0.0437
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0400 - val_loss: 0.0389
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0438 - val_loss: 0.0369
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0397 - val_loss: 0.0359
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0335 - val_loss: 0.0372
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0364 - val_loss: 0.0336
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0331 - val_loss: 0.0361
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0314 - val_loss: 0.0355
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0294 - val_loss: 0.0315
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0298 - val_loss: 0.0292
# Epoch 15/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0271 - val_loss: 0.0338
# Epoch 16/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0276 - val_loss: 0.0280
# Epoch 17/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0230 - val_loss: 0.0261
# Epoch 18/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0224 - val_loss: 0.0253
# Epoch 19/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0256 - val_loss: 0.0287
# Epoch 20/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0297 - val_loss: 0.0315
# Epoch 21/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0259 - val_loss: 0.0271
# Epoch 22/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0267 - val_loss: 0.0304
# Epoch 23/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0276 - val_loss: 0.0277
# Epoch 24/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0230 - val_loss: 0.0278
# Epoch 25/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0223 - val_loss: 0.0268
# Epoch 26/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0231 - val_loss: 0.0280
# Epoch 27/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0226 - val_loss: 0.0246
# Epoch 28/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0205 - val_loss: 0.0260
# Epoch 29/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0186 - val_loss: 0.0254
# Epoch 30/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0246 - val_loss: 0.0236
# Epoch 31/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0213 - val_loss: 0.0257
# Epoch 32/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0264 - val_loss: 0.0307
# Epoch 33/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0261 - val_loss: 0.0268
# Epoch 34/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0267 - val_loss: 0.0262
# Epoch 35/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0248 - val_loss: 0.0230
# Epoch 36/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0202 - val_loss: 0.0234
# Epoch 37/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0214 - val_loss: 0.0243
# Epoch 38/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0220 - val_loss: 0.0244
# Epoch 39/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0233 - val_loss: 0.0235
# Epoch 40/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0199 - val_loss: 0.0229
# Epoch 41/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0207 - val_loss: 0.0230
# Epoch 42/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0187 - val_loss: 0.0234
# Epoch 43/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0213 - val_loss: 0.0247
# Epoch 44/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0200 - val_loss: 0.0227
# Epoch 45/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0204 - val_loss: 0.0221
# Epoch 46/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0184 - val_loss: 0.0229
# Epoch 47/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0184 - val_loss: 0.0235
# Epoch 48/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0203 - val_loss: 0.0233
# Epoch 49/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0183 - val_loss: 0.0243
# Epoch 50/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0188 - val_loss: 0.0223
# Epoch 51/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0222 - val_loss: 0.0219
# Epoch 52/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0175 - val_loss: 0.0218
# Epoch 53/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0172 - val_loss: 0.0220
# Epoch 54/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0194 - val_loss: 0.0256
# Epoch 55/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0191 - val_loss: 0.0222
# Epoch 56/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0208 - val_loss: 0.0217
# Epoch 57/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0163 - val_loss: 0.0246
# Epoch 58/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0177 - val_loss: 0.0253
# Epoch 59/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0192 - val_loss: 0.0210
# Epoch 60/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0153 - val_loss: 0.0264
# Epoch 61/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0186 - val_loss: 0.0234
# Epoch 62/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0175 - val_loss: 0.0209
# Epoch 63/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0187 - val_loss: 0.0211
# Epoch 64/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0184 - val_loss: 0.0211
# Epoch 65/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0188 - val_loss: 0.0213
# Epoch 66/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0178 - val_loss: 0.0208
# Epoch 67/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0170 - val_loss: 0.0230
# Epoch 68/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0172 - val_loss: 0.0223
# Epoch 69/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0198 - val_loss: 0.0253
# Epoch 70/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0195 - val_loss: 0.0219
# Epoch 71/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0166 - val_loss: 0.0203
# Epoch 72/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0149 - val_loss: 0.0211
# Epoch 73/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0147 - val_loss: 0.0209
# Epoch 74/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0173 - val_loss: 0.0195
# Epoch 75/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0167 - val_loss: 0.0214
# Epoch 76/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0152 - val_loss: 0.0201
# Epoch 77/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0170 - val_loss: 0.0202
# Epoch 78/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0166 - val_loss: 0.0187
# Epoch 79/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0165 - val_loss: 0.0201
# Epoch 80/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0169 - val_loss: 0.0302
# Epoch 81/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0159 - val_loss: 0.0254
# Epoch 82/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0183 - val_loss: 0.0199
# Epoch 83/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0203 - val_loss: 0.0258
# Epoch 84/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0185 - val_loss: 0.0245
# Epoch 85/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0164 - val_loss: 0.0223
# Epoch 86/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0179 - val_loss: 0.0220
# Epoch 87/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0161 - val_loss: 0.0203
# Epoch 88/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0162 - val_loss: 0.0192
# Epoch 89/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0176 - val_loss: 0.0202
# Epoch 90/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0170 - val_loss: 0.0222
# Epoch 91/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 92/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0174 - val_loss: 0.0202
# Epoch 93/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0150 - val_loss: 0.0215
# Epoch 94/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0161 - val_loss: 0.0244
# Epoch 95/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0173 - val_loss: 0.0233
# Epoch 96/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0147 - val_loss: 0.0201
# Epoch 97/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0177 - val_loss: 0.0182
# Epoch 98/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0154 - val_loss: 0.0225
# Epoch 99/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0177 - val_loss: 0.0218
# Epoch 100/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0188 - val_loss: 0.0199
# Epoch 101/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0177 - val_loss: 0.0205
# Epoch 102/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0164 - val_loss: 0.0168
# Epoch 103/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0148 - val_loss: 0.0171
# Epoch 104/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0151 - val_loss: 0.0184
# Epoch 105/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0148 - val_loss: 0.0203
# Epoch 106/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0153 - val_loss: 0.0166
# Epoch 107/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0135 - val_loss: 0.0249
# Epoch 108/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0165 - val_loss: 0.0189
# Epoch 109/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0137 - val_loss: 0.0173
# Epoch 110/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0138 - val_loss: 0.0201
# Epoch 111/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0129 - val_loss: 0.0142
# Epoch 112/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0157 - val_loss: 0.0133
# Epoch 113/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0143 - val_loss: 0.0154
# Epoch 114/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0143 - val_loss: 0.0179
# Epoch 115/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0139 - val_loss: 0.0155
# Epoch 116/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0146 - val_loss: 0.0127
# Epoch 117/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0141 - val_loss: 0.0127
# Epoch 118/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0134 - val_loss: 0.0133
# Epoch 119/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0144 - val_loss: 0.0140
# Epoch 120/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0135 - val_loss: 0.0175
# Epoch 121/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0136 - val_loss: 0.0176
# Epoch 122/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0138 - val_loss: 0.0160
# Epoch 123/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0142 - val_loss: 0.0132
# Epoch 124/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0111 - val_loss: 0.0122
# Epoch 125/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 126/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0111 - val_loss: 0.0132
# Epoch 127/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0114 - val_loss: 0.0153
# Epoch 128/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0126 - val_loss: 0.0088
# Epoch 129/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0108 - val_loss: 0.0093
# Epoch 130/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0100 - val_loss: 0.0072
# Epoch 131/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0105 - val_loss: 0.0069
# Epoch 132/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0094 - val_loss: 0.0133
# Epoch 133/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0102 - val_loss: 0.0166
# Epoch 134/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0103 - val_loss: 0.0075
# Epoch 135/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0088 - val_loss: 0.0120
# Epoch 136/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0112 - val_loss: 0.0118
# Epoch 137/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0103 - val_loss: 0.0099
# Epoch 138/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0113 - val_loss: 0.0064
# Epoch 139/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 140/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0097 - val_loss: 0.0132
# Epoch 141/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0111 - val_loss: 0.0059
# Epoch 142/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0115 - val_loss: 0.0050
# Epoch 143/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0091 - val_loss: 0.0163
# Epoch 144/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0095 - val_loss: 0.0098
# Epoch 145/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0081 - val_loss: 0.0086
# Epoch 146/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 147/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0091 - val_loss: 0.0059
# Epoch 148/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0086 - val_loss: 0.0069
# Epoch 149/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0090 - val_loss: 0.0114
# Epoch 150/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0080 - val_loss: 0.0074
# Epoch 151/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0076 - val_loss: 0.0097
# Epoch 152/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0081 - val_loss: 0.0037
# Epoch 153/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 154/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0073 - val_loss: 0.0084
# Epoch 155/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0066 - val_loss: 0.0041
# Epoch 156/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0066 - val_loss: 0.0026
# Epoch 157/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0076 - val_loss: 0.0049
# Epoch 158/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0068 - val_loss: 0.0053
# Epoch 159/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0064 - val_loss: 0.0072
# Epoch 160/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 161/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0060 - val_loss: 0.0035
# Epoch 162/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0060 - val_loss: 0.0025
# Epoch 163/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 164/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0055 - val_loss: 0.0029
# Epoch 165/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 166/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0058 - val_loss: 0.0030
# Epoch 167/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0066 - val_loss: 0.0032
# Epoch 168/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0059 - val_loss: 0.0033
# Epoch 169/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0050 - val_loss: 0.0025
# Epoch 170/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042 - val_loss: 0.0047
# Epoch 171/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0083 - val_loss: 0.0039
# Epoch 172/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0052 - val_loss: 0.0025
# Epoch 173/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0056 - val_loss: 0.0036
# Epoch 174/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0056 - val_loss: 0.0045
# Epoch 175/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 176/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052 - val_loss: 0.0038
# Epoch 177/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 178/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0053 - val_loss: 0.0039
# Epoch 179/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 180/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0047 - val_loss: 0.0020
# Epoch 181/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 182/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - val_loss: 0.0030
# Epoch 183/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 184/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 185/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0047 - val_loss: 0.0020
# Epoch 186/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0051 - val_loss: 0.0023
# Epoch 187/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 188/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0045 - val_loss: 0.0033
# Epoch 189/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 190/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 191/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 192/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 193/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 194/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0041 - val_loss: 0.0027
# Epoch 195/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 196/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0046 - val_loss: 0.0018
# Epoch 197/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 198/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 199/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 200/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040 - val_loss: 0.0021

# %%
# Visualize Model Performance During Training

plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Load Best Model
best_model = load_model(model_location + model_name)

# %%
# Model Prediction
# Predict crop yield for all data splits (scaled results)
y_train_predict = best_model.predict(X_train)
y_val_predict = best_model.predict(X_val)
y_test_predict = best_model.predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
# reverse scaling
y_train_inv = output_scaler.inverse_transform(y_train)
y_val_inv = output_scaler.inverse_transform(y_val)
y_test_inv = output_scaler.inverse_transform(y_test)

y_train_predict_inv = output_scaler.inverse_transform(y_train_predict)
y_val_predict_inv = output_scaler.inverse_transform(y_val_predict)
y_test_predict_inv = output_scaler.inverse_transform(y_test_predict)

# %%
# plot results as scatter
fig = plt.figure(figsize=(12,6))

plt.subplot(1,2,1) # crop yield

# train (blue)
plt.scatter(x=y_train_inv[:,0], y=y_train_predict_inv[:,0], c='blue')
# val (green)
plt.scatter(x=y_val_inv[:,0], y=y_val_predict_inv[:,0], c='green')
# test (red)
plt.scatter(x=y_test_inv[:,0], y=y_test_predict_inv[:,0], c='red')
plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target')
plt.ylabel('Prediction (kg/ha)')
plt.title('Irrigated Crop Yield')

plt.subplot(1,2,2) # irrigation Demand
# train (blue)
plt.scatter(x=y_train_inv[:,1], y=y_train_predict_inv[:,1], c='blue')
# val (green)
plt.scatter(x=y_val_inv[:,1], y=y_val_predict_inv[:,1], c='green')
# test (red)
plt.scatter(x=y_test_inv[:,1], y=y_test_predict_inv[:,1], c='red')
plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target (mm)')
plt.ylabel('Prediction (mm)')
plt.title('Irrigation Demand')
# Out:
# Text(0.5, 1.0, 'Irrigation Demand')

# %%
# Training Scatter Plot

# plot results as scatter
fig = plt.figure(figsize=(12,6))

plt.subplot(1,2,1) # crop yield

# train (blue)
plt.scatter(x=y_train_inv[:,0], y=y_train_predict_inv[:,0], c='blue')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target')
plt.ylabel('Prediction (kg/ha)')
plt.title('Irrigated Crop Yield')

plt.subplot(1,2,2) # irrigation Demand
# train (blue)
plt.scatter(x=y_train_inv[:,1], y=y_train_predict_inv[:,1], c='blue')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target (mm)')
plt.ylabel('Prediction (mm)')
plt.title('Irrigation Demand')
# Out:
# Text(0.5, 1.0, 'Irrigation Demand')

# %%
# Validation Scatter Plot
# plot results as scatter
fig = plt.figure(figsize=(12,6))

plt.subplot(1,2,1) # crop yield


# val (green)
plt.scatter(x=y_val_inv[:,0], y=y_val_predict_inv[:,0], c='green')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target')
plt.ylabel('Prediction (kg/ha)')
plt.title('Irrigated Crop Yield')

plt.subplot(1,2,2) # irrigation Demand

# val (green)
plt.scatter(x=y_val_inv[:,1], y=y_val_predict_inv[:,1], c='green')

plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target (mm)')
plt.ylabel('Prediction (mm)')
plt.title('Irrigation Demand')
# Out:
# Text(0.5, 1.0, 'Irrigation Demand')

# %%
# Testing Scatter Plot

# plot results as scatter
fig = plt.figure(figsize=(12,6))

plt.subplot(1,2,1) # crop yield


# test (red)
plt.scatter(x=y_test_inv[:,0], y=y_test_predict_inv[:,0], c='red')
plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target')
plt.ylabel('Prediction (kg/ha)')
plt.title('Irrigated Crop Yield')

plt.subplot(1,2,2) # irrigation Demand

# test (red)
plt.scatter(x=y_test_inv[:,1], y=y_test_predict_inv[:,1], c='red')
plt.grid(visible=True, which='major', axis='both')
plt.axline([0, 0], [1, 1], c='orange')
plt.xlabel('Target (mm)')
plt.ylabel('Prediction (mm)')
plt.title('Irrigation Demand')
# Out:
# Text(0.5, 1.0, 'Irrigation Demand')

# %%
# Performance Metrics: Train

rmse = root_mean_squared_error(y_train_inv[:,0], y_train_predict_inv[:,0])
r2 = r2_score(y_train_inv[:,0], y_train_predict_inv[:,0])
mae = mean_absolute_error(y_train_inv[:,0], y_train_predict_inv[:,0])

print('RMSE: {:.2f} kg/ha '.format(rmse))
print('MAE: {:.2f} kg/ha'.format(mae))
print('R2: {:.2f}'.format(r2))
print('')

rmse = root_mean_squared_error(y_train_inv[:,1], y_train_predict_inv[:,1])
r2 = r2_score(y_train_inv[:,1], y_train_predict_inv[:,1])
mae = mean_absolute_error(y_train_inv[:,1], y_train_predict_inv[:,1])

print('RMSE: {:.2f} mm '.format(rmse))
print('MAE: {:.2f} mm'.format(mae))
print('R2: {:.2f}'.format(r2))
# Out:
# RMSE: 435.09 kg/ha
# MAE: 348.72 kg/ha
# R2: 0.93
#
# RMSE: 14.15 mm
# MAE: 11.32 mm
# R2: 0.96

# %%
# Performance Metrics: Validation

rmse = root_mean_squared_error(y_val_inv[:,0], y_val_predict_inv[:,0])
r2 = r2_score(y_val_inv[:,0], y_val_predict_inv[:,0])
mae = mean_absolute_error(y_val_inv[:,0], y_val_predict_inv[:,0])

print('RMSE: {:.2f} kg/ha '.format(rmse))
print('MAE: {:.2f} kg/ha'.format(mae))
print('R2: {:.2f}'.format(r2))
print('')

rmse = root_mean_squared_error(y_val_inv[:,1], y_val_predict_inv[:,1])
r2 = r2_score(y_val_inv[:,1], y_val_predict_inv[:,1])
mae = mean_absolute_error(y_val_inv[:,1], y_val_predict_inv[:,1])

print('RMSE: {:.2f} mm '.format(rmse))
print('MAE: {:.2f} mm'.format(mae))
print('R2: {:.2f}'.format(r2))
# Out:
# RMSE: 396.53 kg/ha
# MAE: 326.91 kg/ha
# R2: 0.95
#
# RMSE: 11.28 mm
# MAE: 8.89 mm
# R2: 0.97

# %%
# Performance Metrics: Testing

rmse = root_mean_squared_error(y_test_inv[:,0], y_test_predict_inv[:,0])
r2 = r2_score(y_test_inv[:,0], y_test_predict_inv[:,0])
mae = mean_absolute_error(y_test_inv[:,0], y_test_predict_inv[:,0])

print('RMSE: {:.2f} kg/ha '.format(rmse))
print('MAE: {:.2f} kg/ha'.format(mae))
print('R2: {:.2f}'.format(r2))
print('')

rmse = root_mean_squared_error(y_test_inv[:,1], y_test_predict_inv[:,1])
r2 = r2_score(y_test_inv[:,1], y_test_predict_inv[:,1])
mae = mean_absolute_error(y_test_inv[:,1], y_test_predict_inv[:,1])

print('RMSE: {:.2f} mm '.format(rmse))
print('MAE: {:.2f} mm'.format(mae))
print('R2: {:.2f}'.format(r2))
# Out:
# RMSE: 434.92 kg/ha
# MAE: 330.34 kg/ha
# R2: 0.94
#
# RMSE: 13.32 mm
# MAE: 11.39 mm
# R2: 0.93
